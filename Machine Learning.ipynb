# %%
from preprocessing import Preprocessing
import pandas as pd

# %%
col_drop = ['CustomerId','Surname']
types = {
    'HasCrCard':bool,
    'IsActiveMember':bool
}
train = pd.read_csv('data/train.csv', index_col='id', dtype=types).drop(columns=col_drop)
test = pd.read_csv('data/test.csv', index_col='id', dtype=types).drop(columns=col_drop)

# %%
bank_churn = Preprocessing(train, test, 'Exited')

# %%
X,y,test = bank_churn.encoded()

# %%
X
# Out:
#         CreditScore Gender   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# id
# 0               668      1  33.0       3       0.00              2       True
# 1               627      1  33.0       1       0.00              2       True
# 2               678      1  40.0      10       0.00              2       True
# 3               581      1  34.0       2  148882.54              1       True
# 4               716      1  33.0       5       0.00              2       True
# ...             ...    ...   ...     ...        ...            ...        ...
# 165029          667      0  33.0       2       0.00              1       True
# 165030          792      1  35.0       3       0.00              1      False
# 165031          565      1  31.0       5       0.00              1       True
# 165032          554      0  30.0       7  161533.00              1      False
# 165033          850      1  31.0       1       0.00              1       True
#
# ...

# %%
y
# Out:
# id
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 165029    0
# 165030    0
# 165031    0
# 165032    0
# 165033    1
# Name: Exited, Length: 165034, dtype: int64

# %%
test
# Out:
#         CreditScore Gender   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# id
# 165034          586      0  23.0       2       0.00              2      False
# 165035          683      0  46.0       2       0.00              1       True
# 165036          656      0  34.0       7       0.00              2       True
# 165037          681      1  36.0       8       0.00              1       True
# 165038          752      1  38.0      10  121263.62              1       True
# ...             ...    ...   ...     ...        ...            ...        ...
# 275052          570      1  29.0       7  116099.82              1       True
# 275053          575      0  36.0       4  178032.53              1       True
# 275054          712      1  31.0       2       0.00              2       True
# 275055          709      0  32.0       3       0.00              1       True
# 275056          621      0  37.0       7   87848.39              1       True
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X.loc[:,['CreditScore','Age','EstimatedSalary','Balance']] = scaler.fit_transform(X[['CreditScore','Age','EstimatedSalary','Balance']])

# %%
X
# Out:
#         CreditScore Gender       Age  Tenure   Balance  NumOfProducts  \
# id
# 0             0.636      1  0.202703       3  0.000000              2
# 1             0.554      1  0.202703       1  0.000000              2
# 2             0.656      1  0.297297      10  0.000000              2
# 3             0.462      1  0.216216       2  0.593398              1
# 4             0.732      1  0.202703       5  0.000000              2
# ...             ...    ...       ...     ...       ...            ...
# 165029        0.634      0  0.202703       2  0.000000              1
# 165030        0.884      1  0.229730       3  0.000000              1
# 165031        0.430      1  0.175676       5  0.000000              1
# 165032        0.408      0  0.162162       7  0.643819              1
# 165033        1.000      1  0.175676       1  0.000000              1
#
#         HasCrCard  IsActiveMember  EstimatedSalary  Geography_France  \
# id
# ...
