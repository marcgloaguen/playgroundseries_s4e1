# %%
from preprocessing import Preprocessing
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
col_drop = ['CustomerId','Surname']
types = {
    'HasCrCard':bool,
    'IsActiveMember':bool
}
train = pd.read_csv('data/train.csv', index_col='id', dtype=types).drop(columns=col_drop)
test = pd.read_csv('data/test.csv', index_col='id', dtype=types).drop(columns=col_drop)

# %%
X = train.drop(columns='Exited')
y = train.Exited

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y)

# %%
prepro = Preprocessing()

# %%
X_train_scld = prepro.fit_transform(X_train)
X_test_scld = prepro.transform(X_test)

# %%
X_train_scld
# Out:
#         CreditScore Gender       Age    Tenure   Balance  NumOfProducts  \
# id
# 44266     -0.317411      1  0.210763 -1.075588  1.387064      -1.013262
# 124151     0.182530      0 -1.028316  1.063657 -0.882968       0.814514
# 123699     1.107421      1  0.773981 -1.432129 -0.882968      -1.013262
# 104580    -0.217423      1 -1.253603 -1.075588 -0.882968       0.814514
# 87480      0.719967      0 -0.127168  1.063657 -0.882968       0.814514
# ...             ...    ...       ...       ...       ...            ...
# 85976      0.207527      1  0.323406 -0.362506  0.609856      -1.013262
# 85346     -1.492273      0 -0.127168  1.776738 -0.882968      -1.013262
# 111326     1.407386      1 -0.352455 -1.432129  1.044435       0.814514
# 11977     -0.642373      0  1.449842 -1.432129  0.993981      -1.013262
# 159946     0.669973      1 -0.014524 -1.075588 -0.882968       0.814514
#
#         HasCrCard  IsActiveMember  EstimatedSalary  Geography_France  \
# id
# 44266        True            True        -0.956097              True
# 124151       True           False         0.533407             False
# 123699      False           False        -0.986824              True
# 104580       True            True        -0.589421              True
# 87480        True           False        -1.206923             False
# ...           ...             ...              ...               ...
# 85976        True            True         1.160488              True
# 85346        True            True        -0.957278             False
# 111326       True            True         1.377342              True
# 11977        True            True         1.411280             False
# 159946       True            True        -0.301752              True
#
#         Geography_Germany  Geography_Spain
# id
# 44266               False            False
# 124151              False             True
# 123699              False            False
# 104580              False            False
# 87480               False             True
# ...                   ...              ...
# 85976               False            False
# 85346               False             True
# 111326              False            False
# 11977                True            False
# 159946              False            False
#
# [123775 rows x 12 columns]

# %%
X_test_scld
# Out:
#         CreditScore Gender       Age    Tenure   Balance  NumOfProducts  \
# id
# 1290      -0.079939      1 -1.140960 -1.788669 -0.882968      -1.013262
# 22767      0.332512      1  0.436050 -0.719047  1.372492      -1.013262
# 29309     -1.229804      0 -0.127168 -0.362506 -0.882968       0.814514
# 154982     0.070043      1 -0.465098 -0.005966  1.092680      -1.013262
# 87955      0.919943      1  0.886624 -0.005966  1.355205      -1.013262
# ...             ...    ...       ...       ...       ...            ...
# 157216    -1.979715      0  2.463634 -0.719047  0.687693      -1.013262
# 122940    -1.042326      0  0.210763  1.776738 -0.882968       0.814514
# 50239      0.594982      0  4.716505  1.063657  1.789428      -1.013262
# 59075     -0.117435      1  0.548694  0.707116  0.993284      -1.013262
# 151079     0.532489      0  1.675129  1.776738  1.457603       0.814514
#
#         HasCrCard  IsActiveMember  EstimatedSalary  Geography_France  \
# id
# 1290         True            True         1.247940              True
# 22767        True            True        -0.831119              True
# 29309       False           False        -0.474335              True
# 154982      False            True        -1.098602              True
# 87955        True           False         0.223025             False
# ...           ...             ...              ...               ...
# 157216       True            True         0.063081             False
# 122940      False            True         1.011497              True
# 50239        True            True         1.212280              True
# 59075       False           False        -1.198038             False
# 151079       True            True        -1.568329             False
#
#         Geography_Germany  Geography_Spain
# id
# 1290                False            False
# 22767               False            False
# 29309               False            False
# 154982              False            False
# 87955                True            False
# ...                   ...              ...
# 157216               True            False
# 122940              False            False
# 50239               False            False
# 59075                True            False
# 151079               True            False
#
# [41259 rows x 12 columns]
