# %%
import sys 
sys.path.append('..')

# %%
import numpy as np
import pandas as pd

from preprocessing import Preprocessing
from sklearn.model_selection import StratifiedKFold, GridSearchCV

from xgboost import XGBClassifier

# %%
col_drop = ['CustomerId','Surname']
types = {
    'HasCrCard':bool,
    'IsActiveMember':bool
}
train = pd.read_csv('../data/train.csv', index_col='id', dtype=types).drop(columns=col_drop)
train.drop_duplicates(inplace=True)
X = train.drop(columns='Exited')
y = train.Exited

# %%
prepro = Preprocessing()
X_scld = prepro.fit_transform(X).astype(float)
X_scld.shape
# Out:
# (164911, 91)

# %%
skf = StratifiedKFold(n_splits=4, shuffle=True)
WeightTarget = y.value_counts(True).to_dict()

# %%
params = {
    'booster'                : ['gbtree'],
    'objective'              : ['binary:logistic'],
    'learning_rate'          : [1e-1, 1e-2],
    'n_estimators'           : [50, 100],
    'max_depth'              : [4, 8, 16],
    'subsample'              : [0.8, 0.9, 1.0],
    'eval_metric'            : ['auc']
}
model = XGBClassifier()
grid = GridSearchCV(
    model,
    params,
    scoring = 'roc_auc',
    cv = skf,
    n_jobs = -1,
    verbose=20
)
grid.fit(X_scld,y)
# Out:
# Fitting 4 folds for each of 36 candidates, totalling 144 fits
# [CV 4/4; 1/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic, subsample=0.8
# [CV 4/4; 2/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic, subsample=0.9
# [CV 3/4; 1/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic, subsample=0.8
# [CV 1/4; 1/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic, subsample=0.8
# [CV 1/4; 2/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic, subsample=0.9
# [CV 3/4; 2/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic, subsample=0.9
# [CV 2/4; 3/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic, subsample=1.0
# [CV 3/4; 3/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic, subsample=1.0
# [CV 1/4; 3/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic, subsample=1.0
# [CV 2/4; 2/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic, subsample=0.9
# [CV 2/4; 1/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic, subsample=0.8
# [CV 4/4; 3/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic, subsample=1.0
# [CV 4/4; 2/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic, subsample=0.9;, score=0.889 total time=  18.4s
# [CV 3/4; 2/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic, subsample=0.9;, score=0.887 total time=  18.3s
# [CV 1/4; 4/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=0.8
# [CV 2/4; 4/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=0.8
# [CV 2/4; 2/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic, subsample=0.9;, score=0.888 total time=  18.4s
# [CV 3/4; 4/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=0.8
# [CV 2/4; 1/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic, subsample=0.8;, score=0.888 total time=  18.5s
# [CV 4/4; 4/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=0.8
# [CV 1/4; 1/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic, subsample=0.8;, score=0.889 total time=  18.8s
# [CV 1/4; 5/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=0.9
# [CV 3/4; 1/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic, subsample=0.8;, score=0.887 total time=  18.9s
# [CV 4/4; 3/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic, subsample=1.0;, score=0.889 total time=  18.9s
# [CV 3/4; 3/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic, subsample=1.0;, score=0.888 total time=  18.9s
# [CV 2/4; 5/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=0.9
# [CV 3/4; 5/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=0.9
# [CV 4/4; 5/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=0.9
# [CV 1/4; 3/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic, subsample=1.0;, score=0.888 total time=  19.1s
# [CV 2/4; 3/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic, subsample=1.0;, score=0.888 total time=  19.2s
# [CV 1/4; 6/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=1.0
# [CV 2/4; 6/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=1.0
# [CV 1/4; 2/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic, subsample=0.9;, score=0.889 total time=  25.5s
# [CV 3/4; 6/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=1.0
# [CV 4/4; 1/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic, subsample=0.8;, score=0.889 total time=  25.8s
# [CV 4/4; 6/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=1.0
# [CV 3/4; 5/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=0.9;, score=0.888 total time=  36.8s
# [CV 1/4; 7/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.8
# [CV 2/4; 5/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=0.9;, score=0.888 total time=  37.0s
# [CV 2/4; 7/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.8
# [CV 1/4; 5/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=0.9;, score=0.889 total time=  37.1s
# [CV 3/4; 7/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.8
# [CV 1/4; 4/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=0.8;, score=0.889 total time=  37.9s
# [CV 4/4; 7/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.8
# [CV 3/4; 4/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=0.8;, score=0.888 total time=  37.9s
# [CV 1/4; 8/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.9
# [CV 2/4; 4/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=0.8;, score=0.888 total time=  38.4s
# [CV 4/4; 5/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=0.9;, score=0.890 total time=  37.8s
# [CV 2/4; 8/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.9
# [CV 3/4; 8/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.9
# [CV 4/4; 4/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=0.8;, score=0.890 total time=  38.4s
# [CV 4/4; 8/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.9
# [CV 2/4; 6/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=1.0;, score=0.888 total time=  38.1s
# [CV 1/4; 9/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=1.0
# [CV 1/4; 6/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=1.0;, score=0.890 total time=  38.3s
# [CV 2/4; 9/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=1.0
# [CV 4/4; 6/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=1.0;, score=0.890 total time=  52.8s
# [CV 3/4; 9/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=1.0
# [CV 3/4; 6/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=1.0;, score=0.888 total time=  53.6s
# [CV 4/4; 9/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=1.0
# [CV 2/4; 7/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.8;, score=0.886 total time=  40.5s
# [CV 1/4; 10/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=0.8
# [CV 3/4; 7/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.8;, score=0.886 total time=  40.6s
# [CV 2/4; 10/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=0.8
# [CV 1/4; 7/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.8;, score=0.888 total time=  40.8s
# [CV 3/4; 10/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=0.8
# [CV 3/4; 8/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.9;, score=0.886 total time=  39.9s
# [CV 4/4; 10/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=0.8
# [CV 4/4; 7/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.8;, score=0.888 total time=  40.5s
# [CV 2/4; 8/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.9;, score=0.886 total time=  40.0s
# [CV 1/4; 11/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=0.9
# [CV 2/4; 11/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=0.9
# [CV 1/4; 8/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.9;, score=0.888 total time=  40.4s
# [CV 3/4; 11/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=0.9
# [CV 4/4; 8/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.9;, score=0.888 total time=  40.2s
# [CV 4/4; 11/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=0.9
# [CV 1/4; 9/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=1.0;, score=0.888 total time=  40.6s
# [CV 1/4; 12/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=1.0
# [CV 2/4; 9/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=1.0;, score=0.886 total time=  40.6s
# [CV 2/4; 12/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=1.0
# [CV 3/4; 9/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=1.0;, score=0.886 total time=  53.6s
# [CV 3/4; 12/36] START booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=1.0
# [CV 4/4;
36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=1.0;, score=0.878 total time=  40.5s
# [CV 3/4; 26/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.9
# [CV 2/4; 24/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=1.0;, score=0.878 total time=  40.5s
# [CV 4/4; 26/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.9
# [CV 3/4; 18/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=1.0;, score=0.874 total time= 3.3min
# [CV 1/4; 27/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=1.0
# [CV 4/4; 18/36] END booster=gbtree, eval_metric=auc, learning_rate=0.1, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=1.0;, score=0.876 total time= 3.2min
# [CV 2/4; 27/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=1.0
# [CV 3/4; 24/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=1.0;, score=0.877 total time=  40.5s
# [CV 3/4; 27/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=1.0
# [CV 4/4; 24/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=4, n_estimators=100, objective=binary:logistic, subsample=1.0;, score=0.879 total time=  40.4s
# [CV 4/4; 27/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=1.0
# [CV 1/4; 25/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.8;, score=0.887 total time=  44.7s
# [CV 1/4; 28/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=0.8
# [CV 3/4; 25/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.8;, score=0.885 total time=  44.4s
# [CV 2/4; 25/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.8;, score=0.886 total time=  44.8s
# [CV 2/4; 28/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=0.8
# [CV 3/4; 28/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=0.8
# [CV 4/4; 25/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.8;, score=0.887 total time=  44.4s
# [CV 4/4; 28/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=0.8
# [CV 2/4; 26/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.9;, score=0.886 total time=  43.5s
# [CV 1/4; 29/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=0.9
# [CV 1/4; 26/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.9;, score=0.887 total time=  43.8s
# [CV 2/4; 29/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=0.9
# [CV 3/4; 26/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.9;, score=0.885 total time=  43.7s
# [CV 3/4; 29/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=0.9
# [CV 4/4; 26/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=0.9;, score=0.887 total time=  43.6s
# [CV 4/4; 29/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=0.9
# [CV 1/4; 27/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=1.0;, score=0.887 total time=  44.0s
# [CV 1/4; 30/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=1.0
# [CV 2/4; 27/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=1.0;, score=0.885 total time=  43.6s
# [CV 2/4; 30/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=1.0
# [CV 3/4; 27/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=1.0;, score=0.884 total time=  44.3s
# [CV 3/4; 30/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=1.0
# [CV 4/4; 27/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=50, objective=binary:logistic, subsample=1.0;, score=0.886 total time=  44.4s
# [CV 4/4; 30/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=1.0
# [CV 1/4; 29/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=0.9;, score=0.888 total time= 1.4min
# [CV 1/4; 31/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=50, objective=binary:logistic, subsample=0.8
# [CV 2/4; 29/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=0.9;, score=0.886 total time= 1.4min
# [CV 2/4; 31/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=50, objective=binary:logistic, subsample=0.8
# [CV 4/4; 28/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=0.8;, score=0.887 total time= 1.5min
# [CV 3/4; 31/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=50, objective=binary:logistic, subsample=0.8
# [CV 3/4; 28/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=0.8;, score=0.886 total time= 1.5min
# [CV 4/4; 31/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=50, objective=binary:logistic, subsample=0.8
# [CV 1/4; 28/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=0.8;, score=0.888 total time= 1.5min
# [CV 1/4; 32/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=50, objective=binary:logistic, subsample=0.9
# [CV 2/4; 28/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=0.8;, score=0.886 total time= 1.5min
# [CV 2/4; 32/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=50, objective=binary:logistic, subsample=0.9
# [CV 3/4; 29/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=0.9;, score=0.886 total time= 1.4min
# [CV 3/4; 32/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=50, objective=binary:logistic, subsample=0.9
# [CV 4/4; 29/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=0.9;, score=0.887 total time= 1.4min
# [CV 4/4; 32/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=50, objective=binary:logistic, subsample=0.9
# [CV 1/4; 30/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=1.0;, score=0.887 total time= 1.4min
# [CV 1/4; 33/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=50, objective=binary:logistic, subsample=1.0
# [CV 2/4; 30/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=1.0;, score=0.885 total time= 1.4min
# [CV 2/4; 33/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=50, objective=binary:logistic, subsample=1.0
# [CV 3/4; 30/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=1.0;, score=0.885 total time= 1.4min
# [CV 3/4; 33/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=50, objective=binary:logistic, subsample=1.0
# [CV 4/4; 30/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic, subsample=1.0;, score=0.886 total time= 1.4min
# [CV 4/4; 33/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=50, objective=binary:logistic, subsample=1.0
# [CV 1/4; 31/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=50, objective=binary:logistic, subsample=0.8;, score=0.884 total time= 1.6min
# [CV 1/4; 34/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=0.8
# [CV 2/4; 31/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=50, objective=binary:logistic, subsample=0.8;, score=0.882 total time= 1.6min
# [CV 2/4; 34/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=0.8
# [CV 3/4; 31/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=50, objective=binary:logistic, subsample=0.8;, score=0.880 total time= 1.6min
# [CV 3/4; 34/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=0.8
# [CV 4/4; 31/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=50, objective=binary:logistic, subsample=0.8;, score=0.883 total time= 1.6min
# [CV 4/4; 34/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=0.8
# [CV 1/4; 32/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=50, objective=binary:logistic, subsample=0.9;, score=0.883 total time= 1.6min
# [CV 1/4; 35/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=0.9
# [CV 2/4; 32/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=50, objective=binary:logistic, subsample=0.9;, score=0.881 total time= 1.6min
# [CV 2/4; 35/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=0.9
# [CV 3/4; 32/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=50, objective=binary:logistic, subsample=0.9;, score=0.879 total time= 1.6min
# [CV 3/4; 35/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=0.9
# [CV 4/4; 32/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=50, objective=binary:logistic, subsample=0.9;, score=0.882 total time= 1.6min
# [CV 4/4; 35/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=0.9
# [CV 1/4; 33/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=50, objective=binary:logistic, subsample=1.0;, score=0.878 total time= 1.6min
# [CV 1/4; 36/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=1.0
# [CV 2/4; 33/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=50, objective=binary:logistic, subsample=1.0;, score=0.875 total time= 1.6min
# [CV 2/4; 36/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=1.0
# [CV 4/4; 33/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=50, objective=binary:logistic, subsample=1.0;, score=0.877 total time= 1.6min
# [CV 3/4; 36/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=1.0
# [CV 3/4; 33/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=50, objective=binary:logistic, subsample=1.0;, score=0.874 total time= 1.6min
# [CV 4/4; 36/36] START booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=1.0
# [CV 1/4; 34/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=0.8;, score=0.883 total time= 3.2min
# [CV 2/4; 34/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=0.8;, score=0.881 total time= 3.2min
# [CV 3/4; 34/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=0.8;, score=0.880 total time= 3.2min
# [CV 4/4; 34/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=0.8;, score=0.882 total time= 3.2min
# [CV 1/4; 35/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=0.9;, score=0.883 total time= 3.2min
# [CV 2/4; 35/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=0.9;, score=0.880 total time= 3.2min
# [CV 3/4; 35/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=0.9;, score=0.879 total time= 3.1min
# [CV 4/4; 35/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=0.9;, score=0.882 total time= 3.1min
# [CV 1/4; 36/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=1.0;, score=0.878 total time= 3.1min
# [CV 2/4; 36/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=1.0;, score=0.876 total time= 3.0min
# [CV 3/4; 36/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=1.0;, score=0.874 total time= 3.0min
# [CV 4/4; 36/36] END booster=gbtree, eval_metric=auc, learning_rate=0.01, max_depth=16, n_estimators=100, objective=binary:logistic, subsample=1.0;, score=0.877 total time= 3.0min
# GridSearchCV(cv=StratifiedKFold(n_splits=4, random_state=None, shuffle=True),
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      gpu_id=None, grow_policy=None,
#                                      importance_t...
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'booster': ['gbtree'], 'eval_metric': ['auc'],
#                          'learning_rate': [0.1, 0.01], 'max_depth': [4, 8, 16],
#                          'n_estimators': [50, 100],
#                          'objective': ['binary:logistic'],
#                          'subsample': [0.8, 0.9, 1.0]},
#              scoring='roc_auc', verbose=20)

# %%
grid.best_params_, grid.best_score_
# Out:
# ({'booster': 'gbtree',
#   'eval_metric': 'auc',
#   'learning_rate': 0.1,
#   'max_depth': 4,
#   'n_estimators': 100,
#   'objective': 'binary:logistic',
#   'subsample': 0.9},
#  0.8890587826044398)

# %%
pd.DataFrame(grid.cv_results_).sort_values('rank_test_score').head(10)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 4       37.102719      0.370914         0.072524        0.007383
# 5       45.591372      7.502132         0.083736        0.018032
# 3       38.077344      0.267639         0.070848        0.007557
# 1       20.091259      3.062718         0.059912        0.005980
# 2       18.967576      0.121572         0.060946        0.010498
# 0       20.458404      3.031914         0.060375        0.009283
# 6       40.504701      0.128485         0.091729        0.008992
# 8       47.203688      6.670763         0.103875        0.014734
# 7       40.029122      0.204287         0.091368        0.010085
# 11      85.443568      9.295328         0.145764        0.024750
#
#    param_booster param_eval_metric param_learning_rate param_max_depth  \
# 4         gbtree               auc                 0.1               4
# 5         gbtree               auc                 0.1               4
# 3         gbtree               auc                 0.1               4
# 1         gbtree               auc                 0.1               4
# 2         gbtree               auc                 0.1               4
# 0         gbtree               auc                 0.1               4
# 6         gbtree               auc                 0.1               8
# 8         gbtree               auc                 0.1               8
# 7         gbtree               auc                 0.1               8
# 11        gbtree               auc                 0.1               8
#
#    param_n_estimators  param_objective param_subsample  \
# 4                 100  binary:logistic             0.9
# 5                 100  binary:logistic             1.0
# 3                 100  binary:logistic             0.8
# 1                  50  binary:logistic             0.9
# 2                  50  binary:logistic             1.0
# 0                  50  binary:logistic             0.8
# 6                  50  binary:logistic             0.8
# 8                  50  binary:logistic             1.0
# 7                  50  binary:logistic             0.9
# 11                100  binary:logistic             1.0
#
#                                                params  split0_test_score  \
# 4   {'booster': 'gbtree', 'eval_metric': 'auc', 'l...           0.889483
# 5   {'booster': 'gbtree', 'eval_metric': 'auc', 'l...           0.889508
# 3   {'booster': 'gbtree', 'eval_metric': 'auc', 'l...           0.889383
# 1   {'booster': 'gbtree', 'eval_metric': 'auc', 'l...           0.888711
# 2   {'booster': 'gbtree', 'eval_metric': 'auc', 'l...           0.888466
# 0   {'booster': 'gbtree', 'eval_metric': 'auc', 'l...           0.888627
# 6   {'booster': 'gbtree', 'eval_metric': 'auc', 'l...           0.887947
# 8   {'booster': 'gbtree', 'eval_metric': 'auc', 'l...           0.887808
# 7   {'booster': 'gbtree', 'eval_metric': 'auc', 'l...           0.887594
# 11  {'booster': 'gbtree', 'eval_metric': 'auc', 'l...           0.887726
#
#     split1_test_score  split2_test_score  split3_test_score  mean_test_score  \
# 4            0.888425           0.888423           0.889904         0.889059
# 5            0.888387           0.888310           0.889800         0.889001
# 3            0.888114           0.888402           0.889607         0.888877
# 1            0.887610           0.887426           0.888771         0.888129
# 2            0.887623           0.887583           0.888676         0.888087
# 0            0.887505           0.887436           0.888612         0.888045
# 6            0.886080           0.886494           0.887994         0.887129
# 8            0.886206           0.886252           0.887855         0.887030
# 7            0.885907           0.886383           0.888020         0.886976
# 11           0.886086           0.886307           0.887769         0.886972
#
#     std_test_score  rank_test_score
# 4         0.000652                1
# 5         0.000661                2
# 3         0.000632                3
# 1         0.000615                4
# 2         0.000490                5
# 0         0.000575                6
# 6         0.000855                7
# 8         0.000801                8
# 7         0.000861                9
# 11        0.000780               10
